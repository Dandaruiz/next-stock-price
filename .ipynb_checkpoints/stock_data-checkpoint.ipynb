# %%
import keras
import requests
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation
from keras import optimizers
import numpy as np
from sklearn import preprocessing
np.random.seed(4)
import tensorflow
tensorflow.random.set_seed(1)

history_points = 20

# dataset
url = 'https://api.polygon.io/v2/aggs/ticker/{}/range/1/day/2015-01-01/2020-12-18?apiKey=jXuS6onzWtfNEkQhMJyrCty0ZQIgPsi5'.format('SQ')
response_data = requests.get(url)
results = response_data.json()['results']
results = map(lambda day: [day['o'], day['h'], day['l'], day['c'], day['v']], results)
results = list(results)
results = np.array(results)

data_normaliser = preprocessing.MinMaxScaler()
data_normalised = data_normaliser.fit_transform(results)
    
# using the last {history_points} open close high low volume data points, predict the next open value
ohlcv_histories = np.array([data_normalised[i:i + history_points].copy() for i in range(len(data_normalised) - history_points)])

next_day_open_values_normalised = np.array([data_normalised[:, 0][i + history_points].copy() for i in range(len(data_normalised) - history_points)])
next_day_open_values_normalised = np.expand_dims(next_day_open_values_normalised, -1)

next_day_open_values = np.array([results[:, 0][i + history_points].copy() for i in range(len(results) - history_points)])
next_day_open_values = np.expand_dims(next_day_open_values, -1)

y_normaliser = preprocessing.MinMaxScaler()
y_normaliser.fit(next_day_open_values)

unscaled_y = next_day_open_values
test_split = 0.9
n = int(ohlcv_histories.shape[0] * test_split)

ohlcv_train = ohlcv_histories[:n]
y_train = next_day_open_values_normalised[:n]

ohlcv_test = ohlcv_histories[n:]
y_test = next_day_open_values_normalised[n:]

unscaled_y_test = unscaled_y[n:]

# model architecture

lstm_input = Input(shape=(history_points, 5), name='lstm_input')
x = LSTM(100, name='lstm_0')(lstm_input)
x = Dropout(0.2, name='lstm_dropout_0')(x)
x = Dense(64, name='dense_0')(x)
x = Activation('sigmoid', name='sigmoid_0')(x)
x = Dense(1, name='dense_1')(x)
output = Activation('linear', name='linear_output')(x)

model = Model(inputs=lstm_input, outputs=output)
adam = optimizers.Adam(lr=0.0005)
model.compile(optimizer=adam, loss='mse')
model.fit(x=ohlcv_train, y=y_train, batch_size=32, epochs=50, shuffle=True, validation_split=0.1)


# evaluation

y_test_predicted = model.predict(ohlcv_test)
y_test_predicted = y_normaliser.inverse_transform(y_test_predicted)
y_predicted = model.predict(ohlcv_histories)
y_predicted = y_normaliser.inverse_transform(y_predicted)

assert unscaled_y_test.shape == y_test_predicted.shape
real_mse = np.mean(np.square(unscaled_y_test - y_test_predicted))
scaled_mse = real_mse / (np.max(unscaled_y_test) - np.min(unscaled_y_test)) * 100
print(scaled_mse)

import matplotlib.pyplot as plt

plt.gcf().set_size_inches(22, 15, forward=True)

start = 0
end = -1

real = plt.plot(unscaled_y_test[start:end], label='real')
pred = plt.plot(y_test_predicted[start:end], label='predicted')

# real = plt.plot(unscaled_y[start:end], label='real')
# pred = plt.plot(y_predicted[start:end], label='predicted')

plt.legend(['Real', 'Predicted'])

plt.show()

from datetime import datetime
model.save(f'basic_model.h5')
# Out:
# Epoch 1/50
# 13/13 [==============================] - 3s 67ms/step - loss: 1.8079 - val_loss: 1.3614
# Epoch 2/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.6856 - val_loss: 0.1980
# Epoch 3/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.1406 - val_loss: 0.0243
# Epoch 4/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0364 - val_loss: 0.0031
# Epoch 5/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0146 - val_loss: 0.0096
# Epoch 6/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0089 - val_loss: 0.0112
# Epoch 7/50
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0072 - val_loss: 0.0115
# Epoch 8/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0084 - val_loss: 0.0118
# Epoch 9/50
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0080 - val_loss: 0.0151
# Epoch 10/50
# 13/13 [==============================] - 0s 35ms/step - loss: 0.0075 - val_loss: 0.0138
# Epoch 11/50
# 13/13 [==============================] - 1s 51ms/step - loss: 0.0074 - val_loss: 0.0153
# Epoch 12/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0084 - val_loss: 0.0148
# Epoch 13/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0067 - val_loss: 0.0163
# Epoch 14/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0075 - val_loss: 0.0146
# Epoch 15/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0066 - val_loss: 0.0170
# Epoch 16/50
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0062 - val_loss: 0.0137
# Epoch 17/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0063 - val_loss: 0.0120
# Epoch 18/50
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0060 - val_loss: 0.0180
# Epoch 19/50
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0060 - val_loss: 0.0096
# Epoch 20/50
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0055 - val_loss: 0.0127
# Epoch 21/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0051 - val_loss: 0.0107
# Epoch 22/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0059 - val_loss: 0.0079
# Epoch 23/50
# 13/13 [==============================] - 1s 36ms/step - loss: 0.0051 - val_loss: 0.0080
# Epoch 24/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0052 - val_loss: 0.0076
# Epoch 25/50
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0057 - val_loss: 0.0052
# Epoch 26/50
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0042 - val_loss: 0.0055
# Epoch 27/50
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0048 - val_loss: 0.0060
# Epoch 28/50
# 13/13 [==============================] - 0s 39ms/step - loss: 0.0048 - val_loss: 0.0082
# Epoch 29/50
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0055 - val_loss: 0.0075
# Epoch 30/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0044 - val_loss: 0.0079
# Epoch 31/50
# 13/13 [==============================] - 0s 33ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 32/50
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 33/50
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0041 - val_loss: 0.0049
# Epoch 34/50
# 13/13 [==============================] - 0s 29ms/step - loss: 0.0044 - val_loss: 0.0045
# Epoch 35/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0038 - val_loss: 0.0029
# Epoch 36/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0040 - val_loss: 0.0026
# Epoch 37/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0043 - val_loss: 0.0035
# Epoch 38/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0040 - val_loss: 0.0037
# Epoch 39/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0039 - val_loss: 0.0048
# Epoch 40/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0034 - val_loss: 0.0038
# Epoch 41/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0030 - val_loss: 0.0024
# Epoch 42/50
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 43/50
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0035 - val_loss: 0.0027
# Epoch 44/50
# 13/13 [==============================] - 0s 36ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 45/50
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0037 - val_loss: 0.0022
# Epoch 46/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 47/50
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0038 - val_loss: 0.0021
# Epoch 48/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0027
# Epoch 49/50
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0037 - val_loss: 0.0034
# Epoch 50/50
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0034 - val_loss: 0.0022
# 610.0077422609721
